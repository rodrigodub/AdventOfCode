# %% [markdown]
# # Day 7
# ## No Space Left On Device
#
# You can hear birds chirping and raindrops hitting leaves as the expedition proceeds. Occasionally, you can even hear much louder sounds in the distance; how big do the animals get out here, anyway?
#
# The device the Elves gave you has problems with more than just its communication system. You try to run a system update:
#
# ```
# $ system-update --please --pretty-please-with-sugar-on-top
# Error: No space left on device
# Perhaps you can delete some files to make space for the update?
# ```
# You browse around the filesystem to assess the situation and save the resulting terminal output (your puzzle input). For example:
# ```
# $ cd /
# $ ls
# dir a
# 14848514 b.txt
# 8504156 c.dat
# dir d
# $ cd a
# $ ls
# dir e
# 29116 f
# 2557 g
# 62596 h.lst
# $ cd e
# $ ls
# 584 i
# $ cd ..
# $ cd ..
# $ cd d
# $ ls
# 4060174 j
# 8033020 d.log
# 5626152 d.ext
# 7214296 k
# ```
# The filesystem consists of a tree of files (plain data) and directories (which can contain other directories or files). The outermost directory is called /. You can navigate around the filesystem, moving into or out of directories and listing the contents of the directory you're currently in.
#
# Within the terminal output, lines that begin with $ are **commands you executed**, very much like some modern computers:
#
# - `cd` means change directory. This changes which directory is the current directory, but the specific result depends on the argument:
# - `cd x` moves in one level: it looks in the current directory for the directory named x and makes it the current directory.
# - `cd ..` moves out one level: it finds the directory that contains the current directory, then makes that directory the current directory.
# - `cd /` switches the current directory to the outermost directory, /.
# - `ls` means list. It prints out all of the files and directories immediately contained by the current directory:
# - `123 abc` means that the current directory contains a file named abc with size 123.
# - `dir xyz` means that the current directory contains a directory named xyz.
#
# Given the commands and output in the example above, you can determine that the filesystem looks visually like this:
# ```
# - / (dir)
#   - a (dir)
#     - e (dir)
#       - i (file, size=584)
#     - f (file, size=29116)
#     - g (file, size=2557)
#     - h.lst (file, size=62596)
#   - b.txt (file, size=14848514)
#   - c.dat (file, size=8504156)
#   - d (dir)
#     - j (file, size=4060174)
#     - d.log (file, size=8033020)
#     - d.ext (file, size=5626152)
#     - k (file, size=7214296)
# ```
# Here, there are four directories: / (the outermost directory), a and d (which are in /), and e (which is in a). These directories also contain files of various sizes.
#
# Since the disk is full, your first step should probably be to find directories that are good candidates for deletion. To do this, you need to determine the total size of each directory. The total size of a directory is the sum of the sizes of the files it contains, directly or indirectly. (Directories themselves do not count as having any intrinsic size.)
#
# The total sizes of the directories above can be found as follows:
#
# The total size of directory e is 584 because it contains a single file i of size 584 and no other directories.
# The directory a has total size 94853 because it contains files f (size 29116), g (size 2557), and h.lst (size 62596), plus file i indirectly (a contains e which contains i).
# Directory d has total size 24933642.
# As the outermost directory, / contains every file. Its total size is 48381165, the sum of the size of every file.
# To begin, find all of the directories with a total size of at most 100000, then calculate the sum of their total sizes. In the example above, these directories are a and e; the sum of their total sizes is 95437 (94853 + 584). (As in this example, this process can count files more than once!)
#
# Find all of the directories with a total size of at most 100000. **What is the sum of the total sizes of those directories?**

# %% [markdown]
# ## Part 1
#
# ### Read terminal output

# %%
with open("terminal_output.txt", "r") as f:
    # terminal = f.read()
    terminal = [i.rstrip("\n") for i in f.readlines()]

# %%
# terminal
print(terminal[:200])
# Out:
# ['$ cd /', '$ ls', 'dir fnsvfbzt', 'dir hqdssf', 'dir jwphbz', 'dir lncqsmj', 'dir mhqs', 'dir trwqgzsb', '132067 vjw', 'dir wbsph', '$ cd fnsvfbzt', '$ ls', '62158 sfwnts.hbj', '$ cd ..', '$ cd hqdssf', '$ ls', '45626 cvcbmcm', 'dir dlsmjsbz', 'dir hqdssf', 'dir mhqs', 'dir mtw', 'dir sfccfsrd', 'dir shzgg', '$ cd dlsmjsbz', '$ ls', '9205 qcqbgd.lzd', '$ cd ..', '$ cd hqdssf', '$ ls', '105963 mhqs.zrn', '87909 slwshm.nwr', '$ cd ..', '$ cd mhqs', '$ ls', 'dir ctfl', '45923 jvvl.rcs', 'dir jzjm', 'dir lncqsmj', 'dir mhqs', 'dir wfbvtfmr', '$ cd ctfl', '$ ls', 'dir shzgg', '$ cd shzgg', '$ ls', '18097 cvcbmcm', '289064 mhqs', '208557 slwshm.nwr', '283449 vjw', 'dir wfbvtfmr', '$ cd wfbvtfmr', '$ ls', '263560 dssbpgnl.szh', 'dir hnqjmq', '76551 jvvl.rcs', '195911 lncqsmj', '185776 slwshm.nwr', '$ cd hnqjmq', '$ ls', '3307 rjd.lgh', '$ cd ..', '$ cd ..', '$ cd ..', '$ cd ..', '$ cd jzjm', '$ ls', '31719 rjjrg.pjq', '$ cd ..', '$ cd lncqsmj', '$ ls', 'dir mhqs', '$ cd mhqs', '$ ls', '138296 wfbvtfmr', '$ cd ..', '$ cd ..', '$ cd mhqs', '$ ls', '175499 jvvl.rcs', 'dir rqznrr', '108476 slwshm.nwr', '199853 vjw', '$ cd rqznrr', '$ ls', '105075 shslmlt.spg', '$ cd ..', '$ cd ..', '$ cd wfbvtfmr', '$ ls', '131522 rjjrg.pjq', '$ cd ..', '$ cd ..', '$ cd mtw', '$ ls', 'dir dcgpfrsf', 'dir gwqm', '188911 hqdssf', '34693 jvvl.rcs', 'dir shzgg', '$ cd dcgpfrsf', '$ ls', '47863 dfwthflp.jwq', '203815 dqbqbps.prq', 'dir mhqs', '183653 rqjqpm.bbr', '220694 vjw', '$ cd mhqs', '$ ls', '74450 tjpn', '$ cd ..', '$ cd ..', '$ cd gwqm', '$ ls', 'dir trghjhvs', '$ cd trghjhvs', '$ ls', 'dir shzgg', '2620 slwshm.nwr', '$ cd shzgg', '$ ls', '73435 shzgg.bbf', '$ cd ..', '$ cd ..', '$ cd ..', '$ cd shzgg', '$ ls', '184378 rjjrg.pjq', '$ cd ..', '$ cd ..', '$ cd sfccfsrd', '$ ls', '87317 ccvs.phq', 'dir cqmgf', 'dir cssmfv', 'dir hhhqdmz', '17971 mhqs', 'dir mvjttqr', '264394 slwshm.nwr', 'dir stdzptb', 'dir tcddd', 'dir zmrt', 'dir zqqtb', '$ cd cqmgf', '$ ls', '202804 tcrqqlgs', '$ cd ..', '$ cd cssmfv', '$ ls', '13440 jnhzrtfd', '$ cd ..', '$ cd hhhqdmz', '$ ls', 'dir fdbpld', '272827 jftd.lml', 'dir prqbhbv', 'dir wbzvmz', '$ cd fdbpld', '$ ls', 'dir bgrnz', 'dir dcdj', '78284 jqqfc.tzz', '147731 lbdsh.plp', '269235 ntf.gmq', '$ cd bgrnz', '$ ls', 'dir qzs', 'dir rcv', 'dir wmrmhdd', '$ cd qzs', '$ ls', '156779 lncqsmj.gnf', '$ cd ..', '$ cd rcv', '$ ls', '224927 dvbw.svf', 'dir hqdssf', 'dir jjmsqft', '255189 mhqs.pcl', 'dir mvgqtlm', 'dir pjs', 'dir sljw', '$ cd hqdssf', '$ ls', '63099 blpdwd', '96035 jvvl.rcs', '40533 lvpsmzw', '205031 rjjrg.pjq', '59874 shzgg.ldg', 'dir zdnfpwlw', '$ cd zdnfpwlw', '$ ls', '109325 hqdssf.fmj', '41775 jfqhq.tdn', '203744 nprghch.zjb', 'dir qfs', 'dir rzctqrgm', 'dir shzgg', '$ cd qfs', '$ ls', '234449 vjw']

# %% [markdown]
# ### Try solution with pathlib and pandas

# %%
from pathlib import Path
import pandas as pd

# %%
filesystem_df = pd.DataFrame(columns=["parentdir", "filetype", "name", "size"])

# %%
filesystem_df
# Out:
# Empty DataFrame
# Columns: [parentdir, filetype, name, size]
# Index: []

# %%
filesystem_df = pd.concat([filesystem_df, pd.DataFrame({"name": "rodrigo", "size": 52}, index=[0])])

# %%
filesystem_df = pd.concat([filesystem_df, pd.DataFrame({"name": "daniela", "size": 50, "filetype": "dir"}, 
                                                       index=[test1.index.max()+1])])

# %%
# filesystem_df["parentdir"].fillna("")
filesystem_df.fillna("")
# Out:
#   parentdir filetype     name  size
# 0                     rodrigo    52
# 1                dir  daniela    50

# %% [markdown]
# Seem to work.
#
# ### Initialise dataframe and create function to interpret terminal log

# %%
from pathlib import Path
import pandas as pd

# %%
filesystem_df = pd.DataFrame({"parentdir": Path("/"), "filetype": "dir", "name": "/", "size": 0}, 
                             index=[0])

# %%
filesystem_df
# Out:
#   parentdir filetype name  size
# 0         /      dir    /     0

# %%
def process_terminal_output(terminal_list, filesystem_dataframe):
    # start with root
    the_path = Path("/")
    # navigate (from the second item)
    for output in terminal_list[1:]:
        # interpret output
        arguments = output.split(" ")
        # 1. directory
        if arguments[0] == "dir":
            dict_line = {"parentdir": the_path, "filetype": "dir", "name": arguments[1], "size": 0}
            filesystem_dataframe = pd.concat([filesystem_dataframe, 
                                             pd.DataFrame(dict_line, index=[filesystem_dataframe.index.max()+1])])
            print(f"Added directory {the_path / arguments[1]}")
        # 2. file
        if arguments[0].isdigit():
            dict_line = {"parentdir": the_path, "filetype": "file", "name": arguments[1], "size": int(arguments[0])}
            filesystem_dataframe = pd.concat([filesystem_dataframe, 
                                             pd.DataFrame(dict_line, index=[filesystem_dataframe.index.max()+1])])
            print(f"Added file {the_path / arguments[1]}")
        # 3. changing directory
        if arguments[0] == "$" and arguments[1] == "cd":
            # change to parent
            if arguments[2] == "..":
                the_path = the_path.parent
            # change to child
            else:
                the_path = the_path / arguments[2]
            print(f"Changed to {the_path}")
    # return resulting dataframe
    return filesystem_dataframe

# %% [markdown]
# ### Run process

# %%
filesystem_df = process_terminal_output(terminal, filesystem_df)
# Out:
# Added directory /fnsvfbzt
# Added directory /hqdssf
# Added directory /jwphbz
# Added directory /lncqsmj
# Added directory /mhqs
# Added directory /trwqgzsb
# Added file /vjw
# Added directory /wbsph
# Changed to /fnsvfbzt
# Added file /fnsvfbzt/sfwnts.hbj
# Changed to /
# Changed to /hqdssf
# Added file /hqdssf/cvcbmcm
# Added directory /hqdssf/dlsmjsbz
# Added directory /hqdssf/hqdssf
# Added directory /hqdssf/mhqs
# Added directory /hqdssf/mtw
# Added directory /hqdssf/sfccfsrd
# Added directory /hqdssf/shzgg
# Changed to /hqdssf/dlsmjsbz
# Added file /hqdssf/dlsmjsbz/qcqbgd.lzd
# Changed to /hqdssf
# Changed to /hqdssf/hqdssf
# Added file /hqdssf/hqdssf/mhqs.zrn
# Added file /hqdssf/hqdssf/slwshm.nwr
# Changed to /hqdssf
# Changed to /hqdssf/mhqs
# Added directory /hqdssf/mhqs/ctfl
# Added file /hqdssf/mhqs/jvvl.rcs
# Added directory /hqdssf/mhqs/jzjm
# Added directory /hqdssf/mhqs/lncqsmj
# Added directory /hqdssf/mhqs/mhqs
# Added directory /hqdssf/mhqs/wfbvtfmr
# Changed to /hqdssf/mhqs/ctfl
# Added directory /hqdssf/mhqs/ctfl/shzgg
# Changed to /hqdssf/mhqs/ctfl/shzgg
# Added file /hqdssf/mhqs/ctfl/shzgg/cvcbmcm
# Added file /hqdssf/mhqs/ctfl/shzgg/mhqs
# Added file /hqdssf/mhqs/ctfl/shzgg/slwshm.nwr
# Added file /hqdssf/mhqs/ctfl/shzgg/vjw
# Added directory /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr
# Changed to /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr
# Added file /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/dssbpgnl.szh
# Added directory /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/hnqjmq
# Added file /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/jvvl.rcs
# Added file /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/lncqsmj
# Added file /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/slwshm.nwr
# Changed to /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/hnqjmq
# Added file /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/hnqjmq/rjd.lgh
# Changed to /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr
# Changed to /hqdssf/mhqs/ctfl/shzgg
# Changed to /hqdssf/mhqs/ctfl
# Changed to /hqdssf/mhqs
# Changed to /hqdssf/mhqs/jzjm
# Added file /hqdssf/mhqs/jzjm/rjjrg.pjq
# Changed to /hqdssf/mhqs
# Changed to /hqdssf/mhqs/lncqsmj
# Added directory /hqdssf/mhqs/lncqsmj/mhqs
# Changed to /hqdssf/mhqs/lncqsmj/mhqs
# Added file /hqdssf/mhqs/lncqsmj/mhqs/wfbvtfmr
# Changed to /hqdssf/mhqs/lncqsmj
# Changed to /hqdssf/mhqs
# Changed to /hqdssf/mhqs/mhqs
# Added file /hqdssf/mhqs/mhqs/jvvl.rcs
# Added directory /hqdssf/mhqs/mhqs/rqznrr
# Added file /hqdssf/mhqs/mhqs/slwshm.nwr
# Added file /hqdssf/mhqs/mhqs/vjw
# Changed to /hqdssf/mhqs/mhqs/rqznrr
# Added file /hqdssf/mhqs/mhqs/rqznrr/shslmlt.spg
# Changed to /hqdssf/mhqs/mhqs
# Changed to /hqdssf/mhqs
# Changed to /hqdssf/mhqs/wfbvtfmr
# Added file /hqdssf/mhqs/wfbvtfmr/rjjrg.pjq
# Changed to /hqdssf/mhqs
# Changed to /hqdssf
# Changed to /hqdssf/mtw
# Added directory /hqdssf/mtw/dcgpfrsf
# Added directory /hqdssf/mtw/gwqm
# Added file /hqdssf/mtw/hqdssf
# Added file /hqdssf/mtw/jvvl.rcs
# Added directory /hqdssf/mtw/shzgg
# Changed to /hqdssf/mtw/dcgpfrsf
# Added file /hqdssf/mtw/dcgpfrsf/dfwthflp.jwq
# Added file /hqdssf/mtw/dcgpfrsf/dqbqbps.prq
# Added directory /hqdssf/mtw/dcgpfrsf/mhqs
# Added file /hqdssf/mtw/dcgpfrsf/rqjqpm.bbr
# Added file /hqdssf/mtw/dcgpfrsf/vjw
# Changed to /hqdssf/mtw/dcgpfrsf/mhqs
# Added file /hqdssf/mtw/dcgpfrsf/mhqs/tjpn
# Changed to /hqdssf/mtw/dcgpfrsf
# Changed to /hqdssf/mtw
# Changed to /hqdssf/mtw/gwqm
# Added directory /hqdssf/mtw/gwqm/trghjhvs
# Changed to /hqdssf/mtw/gwqm/trghjhvs
# Added directory /hqdssf/mtw/gwqm/trghjhvs/shzgg
# Added file /hqdssf/mtw/gwqm/trghjhvs/slwshm.nwr
# Changed to /hqdssf/mtw/gwqm/trghjhvs/shzgg
# Added file /hqdssf/mtw/gwqm/trghjhvs/shzgg/shzgg.bbf
# Changed to /hqdssf/mtw/gwqm/trghjhvs
# Changed to /hqdssf/mtw/gwqm
# Changed to /hqdssf/mtw
# Changed to /hqdssf/mtw/shzgg
# Added file /hqdssf/mtw/shzgg/rjjrg.pjq
# Changed to /hqdssf/mtw
# Changed to /hqdssf
# Changed to /hqdssf/sfccfsrd
# Added file /hqdssf/sfccfsrd/ccvs.phq
# Added directory /hqdssf/sfccfsrd/cqmgf
# Added directory /hqdssf/sfccfsrd/cssmfv
# Added directory /hqdssf/sfccfsrd/hhhqdmz
# Added file /hqdssf/sfccfsrd/mhqs
# Added directory /hqdssf/sfccfsrd/mvjttqr
# Added file /hqdssf/sfccfsrd/slwshm.nwr
# Added directory /hqdssf/sfccfsrd/stdzptb
# Added directory /hqdssf/sfccfsrd/tcddd
# Added directory /hqdssf/sfccfsrd/zmrt
# Added directory /hqdssf/sfccfsrd/zqqtb
# Changed to /hqdssf/sfccfsrd/cqmgf
# Added file /hqdssf/sfccfsrd/cqmgf/tcrqqlgs
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/cssmfv
# Added file /hqdssf/sfccfsrd/cssmfv/jnhzrtfd
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/hhhqdmz
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld
# Added file /hqdssf/sfccfsrd/hhhqdmz/jftd.lml
# Added directory /hqdssf/sfccfsrd/hhhqdmz/prqbhbv
# Added directory /hqdssf/sfccfsrd/hhhqdmz/wbzvmz
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/dcdj
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/jqqfc.tzz
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/lbdsh.plp
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/ntf.gmq
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/qzs
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/wmrmhdd
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/qzs
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/qzs/lncqsmj.gnf
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/dvbw.svf
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/jjmsqft
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mhqs.pcl
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/sljw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/blpdwd
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/jvvl.rcs
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/lvpsmzw
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/rjjrg.pjq
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/shzgg.ldg
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/hqdssf.fmj
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/jfqhq.tdn
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/nprghch.zjb
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/qfs
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/rzctqrgm
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/shzgg
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/qfs
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/qfs/vjw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/rzctqrgm
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/rzctqrgm/cvcbmcm
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/shzgg
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/shzgg/mhqs.bds
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/shzgg/rjjrg.pjq
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw/shzgg/vbcjqdjv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf/zdnfpwlw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/jjmsqft
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/jjmsqft/shzgg
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tgtbj
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tmrsn
# Added directory /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/vpv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tgtbj
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tgtbj/lbmv.jcr
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tgtbj/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tmrsn
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/tmrsn/hqdssf.hmh
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/vpv
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm/vpv/jvvl.rcs
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgqtlm
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs/cvcbmcm
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs/jgfphj
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs/pdgnb.qjd
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/sljw
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/sljw/hqdssf.bbn
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/wmrmhdd
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/wmrmhdd/msgcqfbf
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld/dcdj
# Added file /hqdssf/sfccfsrd/hhhqdmz/fdbpld/dcdj/mclcnw
# Changed to /hqdssf/sfccfsrd/hhhqdmz/fdbpld
# Changed to /hqdssf/sfccfsrd/hhhqdmz
# Changed to /hqdssf/sfccfsrd/hhhqdmz/prqbhbv
# Added file /hqdssf/sfccfsrd/hhhqdmz/prqbhbv/bqlcds.pqp
# Added file /hqdssf/sfccfsrd/hhhqdmz/prqbhbv/mhqs
# Added file /hqdssf/sfccfsrd/hhhqdmz/prqbhbv/mvwvdtd.dzf
# Changed to /hqdssf/sfccfsrd/hhhqdmz
# Changed to /hqdssf/sfccfsrd/hhhqdmz/wbzvmz
# Added file /hqdssf/sfccfsrd/hhhqdmz/wbzvmz/tnwgfw
# Changed to /hqdssf/sfccfsrd/hhhqdmz
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/mvjttqr
# Added directory /hqdssf/sfccfsrd/mvjttqr/dtf
# Added directory /hqdssf/sfccfsrd/mvjttqr/frcqdb
# Added directory /hqdssf/sfccfsrd/mvjttqr/hqdssf
# Added file /hqdssf/sfccfsrd/mvjttqr/slwshm.nwr
# Added directory /hqdssf/sfccfsrd/mvjttqr/zdzchmtq
# Changed to /hqdssf/sfccfsrd/mvjttqr/dtf
# Added file /hqdssf/sfccfsrd/mvjttqr/dtf/cvcbmcm
# Added file /hqdssf/sfccfsrd/mvjttqr/dtf/lncqsmj
# Added file /hqdssf/sfccfsrd/mvjttqr/dtf/slwshm.nwr
# Added file /hqdssf/sfccfsrd/mvjttqr/dtf/vjw
# Changed to /hqdssf/sfccfsrd/mvjttqr
# Changed to /hqdssf/sfccfsrd/mvjttqr/frcqdb
# Added file /hqdssf/sfccfsrd/mvjttqr/frcqdb/lncqsmj.mbd
# Added file /hqdssf/sfccfsrd/mvjttqr/frcqdb/slwshm.nwr
# Changed to /hqdssf/sfccfsrd/mvjttqr
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf
# Added directory /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/qnt
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/thdrddd.zmj
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vjw
# Added directory /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vqvzsv.nzg
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm
# Added directory /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm/cnshbf
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm/vjw
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm/cnshbf
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm/cnshbf/hqdssf.mhc
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm/cnshbf/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/hqdssf.stc
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/lncqsmj
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/mhqs.mql
# Added directory /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/tsbtz
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/tsbtz
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/tsbtz/qqfnbd.nqv
# Added file /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/tsbtz/qttbcgd.vtj
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf
# Changed to /hqdssf/sfccfsrd/mvjttqr/hqdssf
# Changed to /hqdssf/sfccfsrd/mvjttqr
# Changed to /hqdssf/sfccfsrd/mvjttqr/zdzchmtq
# Added file /hqdssf/sfccfsrd/mvjttqr/zdzchmtq/lmphsmv
# Added directory /hqdssf/sfccfsrd/mvjttqr/zdzchmtq/nncghrr
# Changed to /hqdssf/sfccfsrd/mvjttqr/zdzchmtq/nncghrr
# Added file /hqdssf/sfccfsrd/mvjttqr/zdzchmtq/nncghrr/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/mvjttqr/zdzchmtq
# Changed to /hqdssf/sfccfsrd/mvjttqr
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/stdzptb
# Added file /hqdssf/sfccfsrd/stdzptb/frsztqqz.mnc
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/tcddd
# Added directory /hqdssf/sfccfsrd/tcddd/hqdssf
# Added file /hqdssf/sfccfsrd/tcddd/jvvl.rcs
# Added directory /hqdssf/sfccfsrd/tcddd/wnzhld
# Changed to /hqdssf/sfccfsrd/tcddd/hqdssf
# Added file /hqdssf/sfccfsrd/tcddd/hqdssf/gcslqrn
# Changed to /hqdssf/sfccfsrd/tcddd
# Changed to /hqdssf/sfccfsrd/tcddd/wnzhld
# Added file /hqdssf/sfccfsrd/tcddd/wnzhld/hpdnj
# Changed to /hqdssf/sfccfsrd/tcddd
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/zmrt
# Added directory /hqdssf/sfccfsrd/zmrt/bmfgjr
# Added directory /hqdssf/sfccfsrd/zmrt/bpztq
# Added directory /hqdssf/sfccfsrd/zmrt/chsh
# Added directory /hqdssf/sfccfsrd/zmrt/dpjhn
# Added file /hqdssf/sfccfsrd/zmrt/mhqs.zvb
# Changed to /hqdssf/sfccfsrd/zmrt/bmfgjr
# Added file /hqdssf/sfccfsrd/zmrt/bmfgjr/jhmgm
# Changed to /hqdssf/sfccfsrd/zmrt
# Changed to /hqdssf/sfccfsrd/zmrt/bpztq
# Added file /hqdssf/sfccfsrd/zmrt/bpztq/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/zmrt
# Changed to /hqdssf/sfccfsrd/zmrt/chsh
# Added file /hqdssf/sfccfsrd/zmrt/chsh/jvvl.rcs
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/lncqsmj
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/njdgplj
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/qhpplfnd
# Added file /hqdssf/sfccfsrd/zmrt/chsh/rjjrg.pjq
# Added file /hqdssf/sfccfsrd/zmrt/chsh/wfbvtfmr.flv
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/lncqsmj
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/lncqsmj/pzd
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/lncqsmj/pzd
# Added file /hqdssf/sfccfsrd/zmrt/chsh/lncqsmj/pzd/vhfjdg.jrz
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/lncqsmj
# Changed to /hqdssf/sfccfsrd/zmrt/chsh
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/cbvz
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/vfhj
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/cbvz
# Added directory /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/cbvz/rtpcsrf
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/cbvz/rtpcsrf
# Added file /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/cbvz/rtpcsrf/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/cbvz
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/vfhj
# Added file /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/vfhj/cbbrgc.wnq
# Added file /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/vfhj/hqdssf
# Added file /hqdssf/sfccfsrd/zmrt/chsh/njdgplj/vfhj/hqdssf.fhn
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/njdgplj
# Changed to /hqdssf/sfccfsrd/zmrt/chsh
# Changed to /hqdssf/sfccfsrd/zmrt/chsh/qhpplfnd
# Added file /hqdssf/sfccfsrd/zmrt/chsh/qhpplfnd/dfththnq.vnm
# Changed to /hqdssf/sfccfsrd/zmrt/chsh
# Changed to /hqdssf/sfccfsrd/zmrt
# Changed to /hqdssf/sfccfsrd/zmrt/dpjhn
# Added file /hqdssf/sfccfsrd/zmrt/dpjhn/rjjrg.pjq
# Added directory /hqdssf/sfccfsrd/zmrt/dpjhn/shzgg
# Changed to /hqdssf/sfccfsrd/zmrt/dpjhn/shzgg
# Added file /hqdssf/sfccfsrd/zmrt/dpjhn/shzgg/cvcbmcm
# Changed to /hqdssf/sfccfsrd/zmrt/dpjhn
# Changed to /hqdssf/sfccfsrd/zmrt
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf/sfccfsrd/zqqtb
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd
# Added file /hqdssf/sfccfsrd/zqqtb/pcz.snl
# Added file /hqdssf/sfccfsrd/zqqtb/slwshm.nwr
# Added file /hqdssf/sfccfsrd/zqqtb/vqm
# Added file /hqdssf/sfccfsrd/zqqtb/wfbvtfmr.stc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/bdbjn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/fjh
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/rqpljw
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/vjw
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/wfbvtfmr.rzb
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/fjh
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/fjh/hqdssf.rqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/blmm.nsv
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mfbd
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/dfzlcv.hjf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/hpqhhmb.sss
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/hqdssf.qcb
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/mbmcfhf.fnj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/rrqjn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/tqjzq.dmg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/rrqjn
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/rrqjn/lncqsmj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/lnnwdbt
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/lnnwdbt
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/lnnwdbt/tnn.bhq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn/wpprqhs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn/wpprqhs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn/wpprqhs/hqdssf
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn/wpprqhs/hqdssf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn/wpprqhs/hqdssf/qbdfzdzw.sgp
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn/wpprqhs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/sgjsn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/wfbvtfmr/hqdssf.chs
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj/wfbvtfmr/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/swrgj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/bmfr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/bzwcswr.mlv
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/dtzwf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/jpsvh.ncc
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/mwbvz
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/shzgg.tbf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/vjw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/bmfr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/bmfr/shzgg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/mwbvz
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/mwbvz/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/ftrv.zcw
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/rjdwmb
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/sfmrwgd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn/smqts.cnc
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn/svdw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn/svdw
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn/svdw/vjtrp
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/jsnlcn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs/hswdjgg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs/rjjrg.pjq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs/hswdjgg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs/hswdjgg/jvvl.rcs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/rjdwmb
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/rjdwmb/twl.lmw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/sfmrwgd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/sfmrwgd/ltwpm.fjl
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/cncdt
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/jrbmlg
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/mhmgn
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/rjjrg.pjq
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/jrbmlg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/jrbmlg/shzgg.bnq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/jvvl.rcs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/mhqs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nfn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nhlbfq
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/phtt.phj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/vjw
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/zmzp.jwg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/mhqs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/mhqs/wpnw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/mhqs/wpnw
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/mhqs/wpnw/lncqsmj.cld
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nfn
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nfn/cvcbmcm
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nfn/mhqs.nst
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nfn/mhqs.vhb
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nfn/slwshm.nwr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nhlbfq
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj/nhlbfq/lncqsmj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/lncqsmj
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/mhmgn
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/mhmgn/vjw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/cvvhvg.pwv
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/gnbm
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/grcfbwdp
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/gzdmzj.wpc
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/mtrqcwrd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/nbtjlnt.srg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/mtrqcwrd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr/mtrqcwrd/shzgg.tbm
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/bswv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/ccvwdrs.dsf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/dctbz.spr
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/shzgg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/slwshm.nwr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/stgp.trm
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/vgdzsrrl.dhg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/shzgg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/shzgg/lncqsmj.vpl
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/shzgg/pbdwbmtd.nlp
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf/shzgg/vlfj.tps
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/hqdssf
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/jvvl.rcs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/rjjrg.pjq
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/lncqsmj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/lncqsmj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/lncqsmj/wfbvtfmr.lfh
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/mhqs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/mhqs/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/mhqs/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/mhqs/wfbvtfmr/gsjwsn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/qqfbsz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/dgf
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/jvvl.rcs
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/rpsjvr.wpb
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/vjw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc/vfcq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc/vfcq
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc/vfcq/fmtfm
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc/vfcq/fmtfm
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc/vfcq/fmtfm/dvbqjq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc/vfcq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm/mjgfpvc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz/rdzsjm
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr/fdtz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn/mhqs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/hnn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/hnn
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/hnn/wfbvtfmr.vhw
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/hnn/zgtln.dwc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt/mhqs.vsg
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt/qnr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt/qnr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt/qnr/llnp.hsh
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd/rzt
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/wmhd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/rqpljw
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/rqpljw/jbv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/cnfb.dgv
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/hqdssf.dtd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/nwvtww
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/brrqp
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/jvvl.rcs
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/lncqsmj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/mhqs
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/rjjrg.pjq
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/rngbhp.ntg
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/shzgg
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wcnh
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/brrqp
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/brrqp/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/clj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/lncqsmj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/scwltjwh.cqd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/vjw
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/wpplgrc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/clj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/clj/grm.pwv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr/whsrtf.gff
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr/wfbvtfmr/cvcbmcm
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/mnsbr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/wpplgrc
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc/wpplgrc/lncqsmj.hwq
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/lncqsmj
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/lncqsmj/jvvl.rcs
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/mhqs
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/mhqs/hqdssf.tbn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/shzgg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/shzgg/lncqsmj.rsg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/shzgg/wfbvtfmr
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wcnh
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wcnh/tmwrh
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wcnh/wml.sht
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wfbvtfmr
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/wfbvtfmr/hqdssf.ctf
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/cvcbmcm
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/gsqzjfn.pmp
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/lncqsmj
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/pbdgbsts
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/pbdgbsts
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/pbdgbsts/vjw
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv/hqdssf.rnn
# Added directory /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv/pcttrtd
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv/pcttrtd
# Added file /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv/pcttrtd/mhqs.gpb
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf
# Changed to /hqdssf/sfccfsrd/zqqtb/ljnmbqvd
# Changed to /hqdssf/sfccfsrd/zqqtb
# Changed to /hqdssf/sfccfsrd
# Changed to /hqdssf
# Changed to /hqdssf/shzgg
# Added file /hqdssf/shzgg/bcn.rws
# Added directory /hqdssf/shzgg/fqwpwcq
# Added directory /hqdssf/shzgg/hngpzst
# Added directory /hqdssf/shzgg/hqdssf
# Added directory /hqdssf/shzgg/shzgg
# Added directory /hqdssf/shzgg/vgjr
# Added directory /hqdssf/shzgg/wfbvtfmr
# Changed to /hqdssf/shzgg/fqwpwcq
# Added file /hqdssf/shzgg/fqwpwcq/mhqs
# Added directory /hqdssf/shzgg/fqwpwcq/pmfv
# Changed to /hqdssf/shzgg/fqwpwcq/pmfv
# Added file /hqdssf/shzgg/fqwpwcq/pmfv/jvvl.rcs
# Added file /hqdssf/shzgg/fqwpwcq/pmfv/pnbm.mlr
# Changed to /hqdssf/shzgg/fqwpwcq
# Changed to /hqdssf/shzgg
# Changed to /hqdssf/shzgg/hngpzst
# Added file /hqdssf/shzgg/hngpzst/cvcbmcm
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm
# Added directory /hqdssf/shzgg/hngpzst/hqdssf
# Added file /hqdssf/shzgg/hngpzst/rjjrg.pjq
# Added directory /hqdssf/shzgg/hngpzst/zjlnsztt
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/dwlfbfjp
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/jvvl.rcs
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/lncqsmj
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/mhqs
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/qzm
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/shzgg.jdf
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/zpgbdnl.twq
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/bdmdpdf.cqg
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/fdc
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/fdc
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/fdc/cvcbmcm
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/qdvss
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/rpwzw
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/wfbvtfmr
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/qdvss
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/qdvss/wqnsrnh
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/rpwzw
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/rpwzw/lfjqvff
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/rpwzw/rdwd
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/wfbvtfmr
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/wfbvtfmr/mhqs
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/wfbvtfmr/slwshm.nwr
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/wfbvtfmr/sncqtvwp.mff
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp/wfbvtfmr/vjw
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf/gwgp
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/hqdssf
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/lncqsmj
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/lncqsmj/dtcjv.lsd
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/lncqsmj/shzgg
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/lncqsmj/vjw
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/mhqs
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/mhqs/stsfrb.gvs
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv/mhqs
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv/mhqs
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv/mhqs/wldhvhl
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qzm
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn
# Added directory /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn/jmmlsvdg
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn/jmmlsvdg
# Added file /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn/jmmlsvdg/rnlgl.vjv
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm/qzm
# Changed to /hqdssf/shzgg/hngpzst/fgzlgbm
# Changed to /hqdssf/shzgg/hngpzst
# Changed to /hqdssf/shzgg/hngpzst/hqdssf
# Added directory /hqdssf/shzgg/hngpzst/hqdssf/mzj
# Changed to /hqdssf/shzgg/hngpzst/hqdssf/mzj
# Added file /hqdssf/shzgg/hngpzst/hqdssf/mzj/sgdn
# Changed to /hqdssf/shzgg/hngpzst/hqdssf
# Changed to /hqdssf/shzgg/hngpzst
# Changed to /hqdssf/shzgg/hngpzst/zjlnsztt
# Added file /hqdssf/shzgg/hngpzst/zjlnsztt/jfj.sgg
# Changed to /hqdssf/shzgg/hngpzst
# Changed to /hqdssf/shzgg
# Changed to /hqdssf/shzgg/hqdssf
# Added file /hqdssf/shzgg/hqdssf/rjjrg.pjq
# Changed to /hqdssf/shzgg
# Changed to /hqdssf/shzgg/shzgg
# Added file /hqdssf/shzgg/shzgg/mhqs.cnb
# Changed to /hqdssf/shzgg
# Changed to /hqdssf/shzgg/vgjr
# Added file /hqdssf/shzgg/vgjr/hclg.vbl
# Added file /hqdssf/shzgg/vgjr/hqdssf
# Added directory /hqdssf/shzgg/vgjr/lncqsmj
# Added file /hqdssf/shzgg/vgjr/nhgwff
# Added file /hqdssf/shzgg/vgjr/qmpdlw
# Added file /hqdssf/shzgg/vgjr/slwshm.nwr
# Changed to /hqdssf/shzgg/vgjr/lncqsmj
# Added file /hqdssf/shzgg/vgjr/lncqsmj/fhpjbpjl.tbh
# Changed to /hqdssf/shzgg/vgjr
# Changed to /hqdssf/shzgg
# Changed to /hqdssf/shzgg/wfbvtfmr
# Added file /hqdssf/shzgg/wfbvtfmr/jvvl.rcs
# Added file /hqdssf/shzgg/wfbvtfmr/rjjrg.pjq
# Added file /hqdssf/shzgg/wfbvtfmr/tctz.rnd
# Changed to /hqdssf/shzgg
# Changed to /hqdssf
# Changed to /
# Changed to /jwphbz
# Added directory /jwphbz/bqbwds
# Added directory /jwphbz/mwnzw
# Added file /jwphbz/qgdsgfg.ngj
# Added file /jwphbz/qtp
# Added file /jwphbz/slwshm.nwr
# Changed to /jwphbz/bqbwds
# Added file /jwphbz/bqbwds/shzgg
# Changed to /jwphbz
# Changed to /jwphbz/mwnzw
# Added file /jwphbz/mwnzw/dtqlr
# Added directory /jwphbz/mwnzw/hlrgzlph
# Added directory /jwphbz/mwnzw/mhqs
# Added file /jwphbz/mwnzw/vjw
# Changed to /jwphbz/mwnzw/hlrgzlph
# Added file /jwphbz/mwnzw/hlrgzlph/hqdssf
# Added file /jwphbz/mwnzw/hlrgzlph/pwdmzwb
# Changed to /jwphbz/mwnzw
# Changed to /jwphbz/mwnzw/mhqs
# Added file /jwphbz/mwnzw/mhqs/rjjrg.pjq
# Changed to /jwphbz/mwnzw
# Changed to /jwphbz
# Changed to /
# Changed to /lncqsmj
# Added directory /lncqsmj/jmsw
# Added directory /lncqsmj/mcgm
# Added directory /lncqsmj/mpc
# Added file /lncqsmj/rjjrg.pjq
# Added file /lncqsmj/shzgg
# Added file /lncqsmj/slwshm.nwr
# Changed to /lncqsmj/jmsw
# Added directory /lncqsmj/jmsw/hqdssf
# Added directory /lncqsmj/jmsw/nmsbdqhm
# Added directory /lncqsmj/jmsw/wfbvtfmr
# Changed to /lncqsmj/jmsw/hqdssf
# Added file /lncqsmj/jmsw/hqdssf/lvzm
# Changed to /lncqsmj/jmsw
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Added directory /lncqsmj/jmsw/nmsbdqhm/czzp
# Added directory /lncqsmj/jmsw/nmsbdqhm/gcp
# Added directory /lncqsmj/jmsw/nmsbdqhm/gsrnmq
# Added directory /lncqsmj/jmsw/nmsbdqhm/rmngvc
# Added directory /lncqsmj/jmsw/nmsbdqhm/vpfq
# Added directory /lncqsmj/jmsw/nmsbdqhm/vpzvb
# Added directory /lncqsmj/jmsw/nmsbdqhm/wccgblsq
# Added file /lncqsmj/jmsw/nmsbdqhm/wfbvtfmr
# Changed to /lncqsmj/jmsw/nmsbdqhm/czzp
# Added file /lncqsmj/jmsw/nmsbdqhm/czzp/slwshm.nwr
# Added file /lncqsmj/jmsw/nmsbdqhm/czzp/wfbvtfmr
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw/nmsbdqhm/gcp
# Added file /lncqsmj/jmsw/nmsbdqhm/gcp/ddsppspd.fcn
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq
# Added directory /lncqsmj/jmsw/nmsbdqhm/gsrnmq/hrsstlt
# Added directory /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/sfpt
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/hrsstlt
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/hrsstlt/mnpc.tmh
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/dmfwf
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/wfbvtfmr.jnz
# Added directory /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz
# Added directory /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/gzsnl
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/lplszs.rvg
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/slwshm.nwr
# Added directory /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/vrnqh
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/gzsnl
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/gzsnl/jvvl.rcs
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/gzsnl/svtppnvt.wrz
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/vrnqh
# Added file /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/vrnqh/jvvl.rcs
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc
# Changed to /lncqsmj/jmsw/nmsbdqhm/gsrnmq
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw/nmsbdqhm/rmngvc
# Added directory /lncqsmj/jmsw/nmsbdqhm/rmngvc/jljbrrgg
# Changed to /lncqsmj/jmsw/nmsbdqhm/rmngvc/jljbrrgg
# Added file /lncqsmj/jmsw/nmsbdqhm/rmngvc/jljbrrgg/cvcbmcm
# Changed to /lncqsmj/jmsw/nmsbdqhm/rmngvc
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw/nmsbdqhm/vpfq
# Added file /lncqsmj/jmsw/nmsbdqhm/vpfq/rjjrg.pjq
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw/nmsbdqhm/vpzvb
# Added file /lncqsmj/jmsw/nmsbdqhm/vpzvb/rjjrg.pjq
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw/nmsbdqhm/wccgblsq
# Added file /lncqsmj/jmsw/nmsbdqhm/wccgblsq/hffzwm.zfr
# Changed to /lncqsmj/jmsw/nmsbdqhm
# Changed to /lncqsmj/jmsw
# Changed to /lncqsmj/jmsw/wfbvtfmr
# Added file /lncqsmj/jmsw/wfbvtfmr/jvvl.rcs
# Added file /lncqsmj/jmsw/wfbvtfmr/mtsb.bwd
# Added file /lncqsmj/jmsw/wfbvtfmr/vcgnlc.cft
# Changed to /lncqsmj/jmsw
# Changed to /lncqsmj
# Changed to /lncqsmj/mcgm
# Added file /lncqsmj/mcgm/cvcbmcm
# Changed to /lncqsmj
# Changed to /lncqsmj/mpc
# Added directory /lncqsmj/mpc/shzgg
# Changed to /lncqsmj/mpc/shzgg
# Added directory /lncqsmj/mpc/shzgg/bnb
# Changed to /lncqsmj/mpc/shzgg/bnb
# Added file /lncqsmj/mpc/shzgg/bnb/lncqsmj.czs
# Changed to /lncqsmj/mpc/shzgg
# Changed to /lncqsmj/mpc
# Changed to /lncqsmj
# Changed to /
# Changed to /mhqs
# Added file /mhqs/jvvl.rcs
# Changed to /
# Changed to /trwqgzsb
# Added file /trwqgzsb/jgphdrnq
# Changed to /
# Changed to /wbsph
# Added directory /wbsph/mhqs
# Added directory /wbsph/vgh
# Changed to /wbsph/mhqs
# Added file /wbsph/mhqs/rfh.zdb
# Changed to /wbsph
# Changed to /wbsph/vgh
# Added file /wbsph/vgh/rjjrg.pjq

# %%
filesystem_df
# Out:
#        parentdir filetype       name    size
# 0              /      dir          /       0
# 1              /      dir   fnsvfbzt       0
# 2              /      dir     hqdssf       0
# 3              /      dir     jwphbz       0
# 4              /      dir    lncqsmj       0
# ..           ...      ...        ...     ...
# 488    /trwqgzsb     file   jgphdrnq   88439
# 489       /wbsph      dir       mhqs       0
# 490       /wbsph      dir        vgh       0
# 491  /wbsph/mhqs     file    rfh.zdb  133965
# 492   /wbsph/vgh     file  rjjrg.pjq   36092
#
# [493 rows x 4 columns]

# %% [markdown]
# ### How many distinct directories?

# %%
filesystem_df["parentdir"].drop_duplicates()
# Out:
# 0                     /
# 501           /fnsvfbzt
# 502             /hqdssf
# 509    /hqdssf/dlsmjsbz
# 510      /hqdssf/hqdssf
#              ...
# 979               /mhqs
# 980           /trwqgzsb
# 981              /wbsph
# 983         /wbsph/mhqs
# 984          /wbsph/vgh
# Name: parentdir, Length: 200, dtype: object

# %%
filesystem_df[filesystem_df["filetype"]=="dir"]["name"].drop_duplicates()
# Out:
# 0             /
# 1      fnsvfbzt
# 2        hqdssf
# 3        jwphbz
# 4       lncqsmj
#          ...
# 468       gzsnl
# 471       vrnqh
# 475    jljbrrgg
# 485         bnb
# 490         vgh
# Name: name, Length: 150, dtype: object

# %% [markdown]
# ### Aggregate directories by size

# %%
dir_sizes_df = pd.DataFrame(filesystem_df.groupby(['parentdir'])['size'].sum())

# %%
dir_sizes_df = dir_sizes_df.reset_index()
dir_sizes_df
# Out:
#             parentdir      size
# 0                   /  42690379
# 1           /fnsvfbzt     62158
# 2             /hqdssf     45626
# 3    /hqdssf/dlsmjsbz      9205
# 4      /hqdssf/hqdssf    193872
# ..                ...       ...
# 195             /mhqs    116955
# 196         /trwqgzsb     88439
# 197            /wbsph         0
# 198       /wbsph/mhqs    133965
# 199        /wbsph/vgh     36092
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Find directories smaller than 100,000 and sum them

# %%
dir_sizes_df[dir_sizes_df["size"] <= 100000]
# Out:
#               parentdir   size
# 1             /fnsvfbzt  62158
# 2               /hqdssf  45626
# 3      /hqdssf/dlsmjsbz   9205
# 5          /hqdssf/mhqs  45923
# 6     /hqdssf/mhqs/ctfl      0
# ..                  ...    ...
# 192        /lncqsmj/mpc      0
# 193  /lncqsmj/mpc/shzgg      0
# 196           /trwqgzsb  88439
# 197              /wbsph      0
# 199          /wbsph/vgh  36092
#
# [76 rows x 2 columns]

# %%
dir_sizes_df[dir_sizes_df["size"] <= 100000]["size"].sum()
# Out:
# 2257410

# %% [markdown]
# #### 2257410
#
# That's not the right answer; your answer is too high. If you're stuck, make sure you're using the full input data; there are also some general tips on the about page, or you can ask for hints on the subreddit. Please wait one minute before trying again. (You guessed 2257410.)

# %% [markdown]
# ### Troubleshooting: test with example

# %%
# troubleshooting
test_terminal = """$ cd /
$ ls
dir a
14848514 b.txt
8504156 c.dat
dir d
$ cd a
$ ls
dir e
29116 f
2557 g
62596 h.lst
$ cd e
$ ls
584 i
$ cd ..
$ cd ..
$ cd d
$ ls
4060174 j
8033020 d.log
5626152 d.ext
7214296 k""".split("\n")
test_terminal
# Out:
# ['$ cd /',
#  '$ ls',
#  'dir a',
#  '14848514 b.txt',
#  '8504156 c.dat',
#  'dir d',
#  '$ cd a',
#  '$ ls',
#  'dir e',
#  '29116 f',
#  '2557 g',
#  '62596 h.lst',
#  '$ cd e',
#  '$ ls',
#  '584 i',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd d',
#  '$ ls',
#  '4060174 j',
#  '8033020 d.log',
#  '5626152 d.ext',
#  '7214296 k']

# %%
# troubleshooting
filesystem_df = pd.DataFrame({"parentdir": Path("/"), "filetype": "dir", "name": "/", "size": 0}, 
                             index=[0])

# %%
# troubleshooting
filesystem_df
# Out:
#   parentdir filetype name  size
# 0         /      dir    /     0

# %%
# troubleshooting
filesystem_df = process_terminal_output(test_terminal, filesystem_df)
# Out:
# Added directory /a
# Added file /b.txt
# Added file /c.dat
# Added directory /d
# Changed to /a
# Added directory /a/e
# Added file /a/f
# Added file /a/g
# Added file /a/h.lst
# Changed to /a/e
# Added file /a/e/i
# Changed to /a
# Changed to /
# Changed to /d
# Added file /d/j
# Added file /d/d.log
# Added file /d/d.ext
# Added file /d/k

# %%
# troubleshooting
filesystem_df
# Out:
#    parentdir filetype   name      size
# 0          /      dir      /         0
# 1          /      dir      a         0
# 2          /     file  b.txt  14848514
# 3          /     file  c.dat   8504156
# 4          /      dir      d         0
# 5         /a      dir      e         0
# 6         /a     file      f     29116
# 7         /a     file      g      2557
# 8         /a     file  h.lst     62596
# 9       /a/e     file      i       584
# 10        /d     file      j   4060174
# 11        /d     file  d.log   8033020
# 12        /d     file  d.ext   5626152
# 13        /d     file      k   7214296

# %%
# troubleshooting
dir_sizes_df = pd.DataFrame(filesystem_df.groupby(['parentdir'])['size'].sum())

# %%
# troubleshooting
dir_sizes_df = dir_sizes_df.reset_index()
dir_sizes_df
# Out:
#   parentdir      size
# 0         /  23352670
# 1        /a     94269
# 2      /a/e       584
# 3        /d  24933642

# %%
# troubleshooting
dir_sizes_df[dir_sizes_df["size"] <= 100000]
# Out:
#   parentdir   size
# 1        /a  94269
# 2      /a/e    584

# %%
# troubleshooting
dir_sizes_df[dir_sizes_df["size"] <= 100000]["size"].sum()
# Out:
# 94853

# %% [markdown]
# This seems strange; this value (94853) is *too low** because `e` should be included in `a` - according to the answer, `a`(=94269+584) plus `e` equals to `95437`

# %% [markdown]
# ### Troubleshooting: test repeat files

# %%
# run from the beginning and...
filesystem_df
# Out:
#        parentdir filetype       name    size
# 0              /      dir          /       0
# 1              /      dir   fnsvfbzt       0
# 2              /      dir     hqdssf       0
# 3              /      dir     jwphbz       0
# 4              /      dir    lncqsmj       0
# ..           ...      ...        ...     ...
# 488    /trwqgzsb     file   jgphdrnq   88439
# 489       /wbsph      dir       mhqs       0
# 490       /wbsph      dir        vgh       0
# 491  /wbsph/mhqs     file    rfh.zdb  133965
# 492   /wbsph/vgh     file  rjjrg.pjq   36092
#
# [493 rows x 4 columns]

# %%
filesystem_df[filesystem_df["filetype"]=="file"]["name"].value_counts()
# there might be something here
# Out:
# rjjrg.pjq       26
# jvvl.rcs        21
# vjw             18
# slwshm.nwr      18
# cvcbmcm         13
#                 ..
# hqdssf.fhn       1
# dfththnq.vnm     1
# pcz.snl          1
# vqm              1
# rfh.zdb          1
# Name: name, Length: 180, dtype: int64

# %%
# Investigate
filesystem_df[filesystem_df["name"]=="rjjrg.pjq"]
# Out:
#                                              parentdir filetype       name  \
# 38                                   /hqdssf/mhqs/jzjm     file  rjjrg.pjq
# 46                               /hqdssf/mhqs/wfbvtfmr     file  rjjrg.pjq
# 62                                   /hqdssf/mtw/shzgg     file  rjjrg.pjq
# 99    /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqdssf     file  rjjrg.pjq
# 111  /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqds...     file  rjjrg.pjq
# 118  /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/mvgq...     file  rjjrg.pjq
# 124      /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/pjs     file  rjjrg.pjq
# 152       /hqdssf/sfccfsrd/mvjttqr/hqdssf/dgdtm/cnshbf     file  rjjrg.pjq
# 161          /hqdssf/sfccfsrd/mvjttqr/zdzchmtq/nncghrr     file  rjjrg.pjq
# 174                        /hqdssf/sfccfsrd/zmrt/bpztq     file  rjjrg.pjq
# 179                         /hqdssf/sfccfsrd/zmrt/chsh     file  rjjrg.pjq
# 191                        /hqdssf/sfccfsrd/zmrt/dpjhn     file  rjjrg.pjq
# 230  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/dltbt/...     file  rjjrg.pjq
# 239  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/...     file  rjjrg.pjq
# 249  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/mhqs/mhqs     file  rjjrg.pjq
# 260  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...     file  rjjrg.pjq
# 296  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...     file  rjjrg.pjq
# 331      /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn     file  rjjrg.pjq
# 378                              /hqdssf/shzgg/hngpzst     file  rjjrg.pjq
# 415                               /hqdssf/shzgg/hqdssf     file  rjjrg.pjq
# 425                             /hqdssf/shzgg/wfbvtfmr     file  rjjrg.pjq
# 439                                 /jwphbz/mwnzw/mhqs     file  rjjrg.pjq
# 443                                           /lncqsmj     file  rjjrg.pjq
# 477                        /lncqsmj/jmsw/nmsbdqhm/vpfq     file  rjjrg.pjq
# 478                       /lncqsmj/jmsw/nmsbdqhm/vpzvb     file  rjjrg.pjq
# 492                                         /wbsph/vgh     file  rjjrg.pjq
#
#        size
# 38    31719
# 46   131522
# 62   184378
# 99   205031
# 111  126331
# 118  202755
# 124  162974
# 152  122945
# 161  180468
# 174  184906
# 179  190460
# 191  127322
# 230  123953
# 239  156668
# 249   30326
# 260   65380
# 296   42472
# 331  107908
# 378     378
# 415     906
# 425   47525
# 439  176337
# 443  233050
# 477   73628
# 478  265609
# 492   36092

# %%
filesystem_df.value_counts()
# Out:
# parentdir                                            filetype  name         size
# /                                                    dir       /            0         1
# /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/frqcc  dir       wpplgrc      0         1
#                                                                clj          0         1
# /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/brrqp  file      wfbvtfmr     270783    1
# /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn        file      rngbhp.ntg   286918    1
#                                                                                      ..
# /hqdssf/sfccfsrd/mvjttqr/zdzchmtq                    file      lmphsmv      271886    1
#                                                      dir       nncghrr      0         1
# /hqdssf/sfccfsrd/mvjttqr/hqdssf/vpqjmmf/tsbtz        file      qttbcgd.vtj  59649     1
#                                                                qqfnbd.nqv   244065    1
# /wbsph/vgh                                           file      rjjrg.pjq    36092     1
# Length: 493, dtype: int64

# %% [markdown]
# ### Second approach: find the size of each dir and all its subdirectories

# %%
filesystem_df
# Out:
#        parentdir filetype       name    size
# 0              /      dir          /       0
# 1              /      dir   fnsvfbzt       0
# 2              /      dir     hqdssf       0
# 3              /      dir     jwphbz       0
# 4              /      dir    lncqsmj       0
# ..           ...      ...        ...     ...
# 488    /trwqgzsb     file   jgphdrnq   88439
# 489       /wbsph      dir       mhqs       0
# 490       /wbsph      dir        vgh       0
# 491  /wbsph/mhqs     file    rfh.zdb  133965
# 492   /wbsph/vgh     file  rjjrg.pjq   36092
#
# [493 rows x 4 columns]

# %%
# How many distinct directories?
filesystem_df["parentdir"].drop_duplicates()
# Out:
# 0                     /
# 9             /fnsvfbzt
# 10              /hqdssf
# 17     /hqdssf/dlsmjsbz
# 18       /hqdssf/hqdssf
#              ...
# 487               /mhqs
# 488           /trwqgzsb
# 489              /wbsph
# 491         /wbsph/mhqs
# 492          /wbsph/vgh
# Name: parentdir, Length: 200, dtype: object

# %%
filesystem_df[filesystem_df["filetype"]=="dir"]["name"].drop_duplicates()
# Out:
# 0             /
# 1      fnsvfbzt
# 2        hqdssf
# 3        jwphbz
# 4       lncqsmj
#          ...
# 468       gzsnl
# 471       vrnqh
# 475    jljbrrgg
# 485         bnb
# 490         vgh
# Name: name, Length: 150, dtype: object

# %%
# Aggregate directories by size
dir_sizes_df = pd.DataFrame(filesystem_df.groupby(['parentdir'])['size'].sum())

# %%
dir_sizes_df = dir_sizes_df.reset_index()
dir_sizes_df
# Out:
#             parentdir    size
# 0                   /  132067
# 1           /fnsvfbzt   62158
# 2             /hqdssf   45626
# 3    /hqdssf/dlsmjsbz    9205
# 4      /hqdssf/hqdssf  193872
# ..                ...     ...
# 195             /mhqs  116955
# 196         /trwqgzsb   88439
# 197            /wbsph       0
# 198       /wbsph/mhqs  133965
# 199        /wbsph/vgh   36092
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Calculate the size of all subdirectories within a given directory

# %%
dir_sizes_df["parentdir_txt"] = dir_sizes_df["parentdir"].apply(lambda x: f"{x}")
dir_sizes_df
# Out:
#             parentdir    size     parentdir_txt
# 0                   /  132067                 /
# 1           /fnsvfbzt   62158         /fnsvfbzt
# 2             /hqdssf   45626           /hqdssf
# 3    /hqdssf/dlsmjsbz    9205  /hqdssf/dlsmjsbz
# 4      /hqdssf/hqdssf  193872    /hqdssf/hqdssf
# ..                ...     ...               ...
# 195             /mhqs  116955             /mhqs
# 196         /trwqgzsb   88439         /trwqgzsb
# 197            /wbsph       0            /wbsph
# 198       /wbsph/mhqs  133965       /wbsph/mhqs
# 199        /wbsph/vgh   36092        /wbsph/vgh
#
# [200 rows x 3 columns]

# %%
def calculate_subdirectories_size(dataframe, directory):
    return dataframe[dataframe["parentdir_txt"].str.contains(directory)]['size'].sum()

# %%
dir_sizes_df["subdir_size"] = dir_sizes_df["parentdir_txt"].apply(
    lambda x: calculate_subdirectories_size(dir_sizes_df, x))
dir_sizes_df
# Out:
#             parentdir    size     parentdir_txt  subdir_size
# 0                   /  132067                 /     42558312
# 1           /fnsvfbzt   62158         /fnsvfbzt        62158
# 2             /hqdssf   45626           /hqdssf     37225320
# 3    /hqdssf/dlsmjsbz    9205  /hqdssf/dlsmjsbz         9205
# 4      /hqdssf/hqdssf  193872    /hqdssf/hqdssf       193872
# ..                ...     ...               ...          ...
# 195             /mhqs  116955             /mhqs      5831886
# 196         /trwqgzsb   88439         /trwqgzsb        88439
# 197            /wbsph       0            /wbsph       170057
# 198       /wbsph/mhqs  133965       /wbsph/mhqs       133965
# 199        /wbsph/vgh   36092        /wbsph/vgh        36092
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Find directories smaller than 100,000 and sum them

# %%
dir_sizes_df[dir_sizes_df["subdir_size"] <= 100000]
# Out:
#                                              parentdir   size  \
# 1                                            /fnsvfbzt  62158
# 3                                     /hqdssf/dlsmjsbz   9205
# 9              /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/hnqjmq   3307
# 10                                   /hqdssf/mhqs/jzjm  31719
# 18                           /hqdssf/mtw/dcgpfrsf/mhqs  74450
# 19                                    /hqdssf/mtw/gwqm      0
# 20                           /hqdssf/mtw/gwqm/trghjhvs   2620
# 21                     /hqdssf/mtw/gwqm/trghjhvs/shzgg  73435
# 25                             /hqdssf/sfccfsrd/cssmfv  13440
# 34   /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqds...  99041
# 36   /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/jjmsqft  47522
# 42      /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/sljw  61689
# 43       /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/wmrmhdd  92888
# 44                /hqdssf/sfccfsrd/hhhqdmz/fdbpld/dcdj  99280
# 57                            /hqdssf/sfccfsrd/stdzptb  19398
# 87   /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/...  19937
# 98   /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...  37975
# 104  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...  85806
# 129  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/...  31407
# 131  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/...  81283
# 133  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/...   8972
# 139  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/pbd...  92092
# 140    /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv  41213
# 141  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znv...  16759
# 155             /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv      0
# 156        /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv/mhqs  91378
# 157                  /hqdssf/shzgg/hngpzst/fgzlgbm/qzm      0
# 158              /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn      0
# 159     /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn/jmmlsvdg  41383
# 162                     /hqdssf/shzgg/hngpzst/zjlnsztt  78315
# 163                               /hqdssf/shzgg/hqdssf    906
# 169                                     /jwphbz/bqbwds  18049
# 175                               /lncqsmj/jmsw/hqdssf  44806
# 180              /lncqsmj/jmsw/nmsbdqhm/gsrnmq/hrsstlt  18477
# 184      /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/vrnqh  94389
# 187                        /lncqsmj/jmsw/nmsbdqhm/vpfq  73628
# 196                                          /trwqgzsb  88439
# 199                                         /wbsph/vgh  36092
#
#                                          parentdir_txt  subdir_size
# 1                                            /fnsvfbzt        62158
# 3                                     /hqdssf/dlsmjsbz         9205
# 9              /hqdssf/mhqs/ctfl/shzgg/wfbvtfmr/hnqjmq         3307
# 10                                   /hqdssf/mhqs/jzjm        31719
# 18                           /hqdssf/mtw/dcgpfrsf/mhqs        74450
# 19                                    /hqdssf/mtw/gwqm        76055
# 20                           /hqdssf/mtw/gwqm/trghjhvs        76055
# 21                     /hqdssf/mtw/gwqm/trghjhvs/shzgg        73435
# 25                             /hqdssf/sfccfsrd/cssmfv        13440
# 34   /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/hqds...        99041
# 36   /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/jjmsqft        47522
# 42      /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv/sljw        61689
# 43       /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/wmrmhdd        92888
# 44                /hqdssf/sfccfsrd/hhhqdmz/fdbpld/dcdj        99280
# 57                            /hqdssf/sfccfsrd/stdzptb        19398
# 87   /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/htbzp/...        19937
# 98   /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...        37975
# 104  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...        85806
# 129  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/...        31407
# 131  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/...        81283
# 133  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/qblrnn/...         8972
# 139  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/pbd...        92092
# 140    /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znvv        57972
# 141  /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf/tdg/znv...        16759
# 155             /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv        91378
# 156        /hqdssf/shzgg/hngpzst/fgzlgbm/qfjmtvpv/mhqs        91378
# 157                  /hqdssf/shzgg/hngpzst/fgzlgbm/qzm        41383
# 158              /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn        41383
# 159     /hqdssf/shzgg/hngpzst/fgzlgbm/qzm/shn/jmmlsvdg        41383
# 162                     /hqdssf/shzgg/hngpzst/zjlnsztt        78315
# 163                               /hqdssf/shzgg/hqdssf          906
# 169                                     /jwphbz/bqbwds        18049
# 175                               /lncqsmj/jmsw/hqdssf        44806
# 180              /lncqsmj/jmsw/nmsbdqhm/gsrnmq/hrsstlt        18477
# 184      /lncqsmj/jmsw/nmsbdqhm/gsrnmq/rzc/zsnmz/vrnqh        94389
# 187                        /lncqsmj/jmsw/nmsbdqhm/vpfq        73628
# 196                                          /trwqgzsb        88439
# 199                                         /wbsph/vgh        36092

# %%
dir_sizes_df[dir_sizes_df["subdir_size"] <= 100000]["subdir_size"].sum()
# Out:
# 2031851

# %% [markdown]
# #### 2031851
#
# That's the right answer! You are one gold star closer to collecting enough star fruit.
#
# Your puzzle answer was 2031851.
#
# The first half of this puzzle is complete! It provides one gold star: *
#
# ## Part Two
# Now, you're ready to choose a directory to delete.
#
# The total disk space available to the filesystem is `70000000`. To run the update, you need unused space of at least `30000000`. You need to find a directory you can delete that will free up enough space to run the update.
#
# In the example above, the total size of the outermost directory (and thus the total amount of used space) is `48381165`; this means that the size of the unused space must currently be `21618835`, which isn't quite the `30000000` required by the update. Therefore, the update still requires a directory with total size of at least `8381165` to be deleted before it can run.
#
# To achieve this, you have the following options:
#
# - Delete directory `e`, which would increase unused space by `584`.
# - Delete directory `a`, which would increase unused space by `94853`.
# - Delete directory `d`, which would increase unused space by `24933642`.
# - Delete directory `/`, which would increase unused space by `48381165`.
#
# Directories `e` and `a` are both too small; deleting them would not free up enough space. However, directories `d` and `/` are both big enough! Between these, choose the **smallest**: `d`, increasing unused space by 24933642.
#
# Find the smallest directory that, if deleted, would free up enough space on the filesystem to run the update. **What is the total size of that directory?**

# %% [markdown]
# ### House cleanup first: confirm size of used space with test dataset

# %%
# troubleshooting
filesystem_test_df = pd.DataFrame({"parentdir": Path("/"), "filetype": "dir", "name": "/", "size": 0}, 
                             index=[0])
filesystem_test_df = process_terminal_output(test_terminal, filesystem_test_df)
dir_sizes_test_df = pd.DataFrame(filesystem_test_df.groupby(['parentdir'])['size'].sum())
dir_sizes_test_df = dir_sizes_test_df.reset_index()
dir_sizes_test_df["parentdir_txt"] = dir_sizes_test_df["parentdir"].apply(lambda x: f"{x}")
dir_sizes_test_df["subdir_size"] = dir_sizes_test_df["parentdir_txt"].apply(
    lambda x: calculate_subdirectories_size(dir_sizes_test_df, x))
dir_sizes_test_df[dir_sizes_test_df["subdir_size"] <= 100000]
# Out:
# Added directory /a
# Added file /b.txt
# Added file /c.dat
# Added directory /d
# Changed to /a
# Added directory /a/e
# Added file /a/f
# Added file /a/g
# Added file /a/h.lst
# Changed to /a/e
# Added file /a/e/i
# Changed to /a
# Changed to /
# Changed to /d
# Added file /d/j
# Added file /d/d.log
# Added file /d/d.ext
# Added file /d/k
#   parentdir   size parentdir_txt  subdir_size
# 1        /a  94269            /a        94853
# 2      /a/e    584          /a/e          584

# %%
dir_sizes_test_df[dir_sizes_test_df["subdir_size"] <= 100000]["subdir_size"].sum()
# Out:
# 95437

# %%
dir_sizes_test_df
# Out:
#   parentdir      size parentdir_txt  subdir_size
# 0         /  23352670             /     48381165
# 1        /a     94269            /a        94853
# 2      /a/e       584          /a/e          584
# 3        /d  24933642            /d     24933642

# %% [markdown]
# #### 48,381,165 OK

# %% [markdown]
# ### Problem solving
#
# > Find the smallest directory that, if deleted, would free up enough space on the filesystem to run the update. *What is the total size of that directory?*

# %%
total_disk_space = 70000000
total_size_outermost_directory = dir_sizes_df[dir_sizes_df["parentdir_txt"]=="/"]["subdir_size"][0]
required_space = 30000000
available_space = total_disk_space - total_size_outermost_directory
delete_required = required_space - available_space

# %%
print(f"Total disk space available to the filesystem: {total_disk_space}\n" \
      f"Total size of the outermost directory: {total_size_outermost_directory}\n" \
      f"Required space: {required_space}\n" \
      f"Available space: {available_space}\n" \
      f"Required delete size: {delete_required}")
# Out:
# Total disk space available to the filesystem: 70000000
# Total size of the outermost directory: 42558312
# Required space: 30000000
# Available space: 27441688
# Required delete size: 2558312

# %%
dir_sizes_df
# Out:
#             parentdir    size     parentdir_txt  subdir_size
# 0                   /  132067                 /     42558312
# 1           /fnsvfbzt   62158         /fnsvfbzt        62158
# 2             /hqdssf   45626           /hqdssf     37225320
# 3    /hqdssf/dlsmjsbz    9205  /hqdssf/dlsmjsbz         9205
# 4      /hqdssf/hqdssf  193872    /hqdssf/hqdssf       193872
# ..                ...     ...               ...          ...
# 195             /mhqs  116955             /mhqs      5831886
# 196         /trwqgzsb   88439         /trwqgzsb        88439
# 197            /wbsph       0            /wbsph       170057
# 198       /wbsph/mhqs  133965       /wbsph/mhqs       133965
# 199        /wbsph/vgh   36092        /wbsph/vgh        36092
#
# [200 rows x 4 columns]

# %%
dir_sizes_df[dir_sizes_df["subdir_size"] >= delete_required].sort_values(["subdir_size"], ascending=True)
# Out:
#                                              parentdir    size  \
# 61                               /hqdssf/sfccfsrd/zmrt  288144
# 174                                      /lncqsmj/jmsw       0
# 146                      /hqdssf/shzgg/hngpzst/fgzlgbm  664089
# 97   /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...  186412
# 145                              /hqdssf/shzgg/hngpzst   18808
# 125             /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf  367869
# 30           /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv  480116
# 47                            /hqdssf/sfccfsrd/mvjttqr   55645
# 28               /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz       0
# 27                     /hqdssf/sfccfsrd/hhhqdmz/fdbpld  495250
# 96    /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn       0
# 26                            /hqdssf/sfccfsrd/hhhqdmz  272827
# 142                                      /hqdssf/shzgg   19544
# 195                                              /mhqs  116955
# 173                                           /lncqsmj  514382
# 77             /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz  397713
# 75                     /hqdssf/sfccfsrd/zqqtb/ljnmbqvd  767461
# 74                              /hqdssf/sfccfsrd/zqqtb  518684
# 23                                    /hqdssf/sfccfsrd  369682
# 2                                              /hqdssf   45626
# 0                                                    /  132067
#
#                                          parentdir_txt  subdir_size
# 61                               /hqdssf/sfccfsrd/zmrt      2568781
# 174                                      /lncqsmj/jmsw      2654809
# 146                      /hqdssf/shzgg/hngpzst/fgzlgbm      3054935
# 97   /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrw...      3161529
# 145                              /hqdssf/shzgg/hngpzst      3321697
# 125             /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/tzjftf      3331150
# 30           /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz/rcv      3466202
# 47                            /hqdssf/sfccfsrd/mvjttqr      3681111
# 28               /hqdssf/sfccfsrd/hhhqdmz/fdbpld/bgrnz      3715869
# 27                     /hqdssf/sfccfsrd/hhhqdmz/fdbpld      4310399
# 96    /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz/vgbvrwvn      5140153
# 26                            /hqdssf/sfccfsrd/hhhqdmz      5362682
# 142                                      /hqdssf/shzgg      5619737
# 195                                              /mhqs      5831886
# 173                                           /lncqsmj      6881165
# 77             /hqdssf/sfccfsrd/zqqtb/ljnmbqvd/qpclpbz     10148525
# 75                     /hqdssf/sfccfsrd/zqqtb/ljnmbqvd     14694309
# 74                              /hqdssf/sfccfsrd/zqqtb     15212993
# 23                                    /hqdssf/sfccfsrd     27886955
# 2                                              /hqdssf     37225320
# 0                                                    /     42558312

# %%
above_reqs_df = dir_sizes_df[dir_sizes_df["subdir_size"] >= 
                             delete_required].sort_values(["subdir_size"], ascending=True)

# %%
above_reqs_df.loc[61, "subdir_size"]
# Out:
# 2568781

# %% [markdown]
# #### 2568781
#
# That's the right answer! You are one gold star closer to collecting enough star fruit.
#
# You have completed Day 7!
